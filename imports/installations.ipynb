# %% [markdown]
# # Installations

# %% [markdown]
# List of installed and used packages:
# - NumPy
# - Pandas
# - Seaborn
# - Matplotlib
# - Scikit Learn

# %%
# %pip install numpy

# %%
# %pip install pandas

# %%
# %pip install seaborn

# %%
# %pip install matplotlib

# %%
# %pip install scikit-learn
