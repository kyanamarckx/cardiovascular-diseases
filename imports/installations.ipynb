# %% [markdown]
# # :sparkling_heart: Installations

# %% [markdown]
# List of installed and used packages:
# - Scipy
# - Pandas
# - Seaborn
# - Matplotlib
# - Scikit Learn

# %%
# %pip install scipy

# %%
# %pip install pandas

# %%
# %pip install seaborn

# %%
# %pip install matplotlib

# %%
# %pip install scikit-learn
